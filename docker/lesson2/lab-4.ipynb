# %% [markdown]
# 项目架构图

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !docker-compose -f ../../labs/lab4/docker-compose.yml up
# Out:
# Starting lab4_rabbitmq_1_8f57e2ca7263 ...
# Starting lab4_redis_1_3208c4e13ab4    ...
# Starting lab4_backend_1_4d80b32722e3  ...
# Starting lab4_caculate_1_3aa2643624f8 ...
# Starting lab4_frontend_1_56c39241c138 ...
# Starting lab4_notification_1_e0d8bed60636 ...
# Attaching to lab4_caculate_1_3aa2643624f8, lab4_redis_1_3208c4e13ab4, lab4_backend_1_4d80b32722e3, lab4_frontend_1_56c39241c138, lab4_rabbitmq_1_8f57e2ca7263, lab4_notification_1_e0d8bed60636
# redis_1_3208c4e13ab4 | 1:C 04 Dec 2018 04:37:02.922 # oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# redis_1_3208c4e13ab4 | 1:C 04 Dec 2018 04:37:02.922 # Redis version=5.0.1, bits=64, commit=00000000, modified=0, pid=1, just started
# redis_1_3208c4e13ab4 | 1:C 04 Dec 2018 04:37:02.922 # Warning: no config file specified, using the default config. In order to specify a config file use redis-server /path/to/redis.conf
# redis_1_3208c4e13ab4 | 1:M 04 Dec 2018 04:37:02.923 * Running mode=standalone, port=6379.
# ...

# %% [markdown]
# 打开浏览器http://localhost:3000/
